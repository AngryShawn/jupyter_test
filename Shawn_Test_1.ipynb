# %% [markdown]
# Behold the awesomeness of my skillZ!

# %%
print('''Woe to you, oh Earth and sea, for the Devil sends the Beast with wrath
Because he knows the time is short
Let him who hath understanding reckon the number of the Beast
For it is a human number, its number is''')
a = 3
b = 222
sum = a * b
print(sum)

print('or')
str1 = 'six '
str2 = 'hundred '
str3 = 'sixty '
str4 = 'six '
print(str1 + str2 + str3 + str4)
print('or')
print (str1 *3)
# Out:
# Woe to you, oh Earth and sea, for the Devil sends the Beast with wrath
# Because he knows the time is short
# Let him who hath understanding reckon the number of the Beast
# For it is a human number, its number is
# 666
# or
# six hundred sixty six
# or
# six six six

# %% [markdown]
# now who doesn't love some good old fashioned metal, hmm?

# %% [markdown]
# ![bruce.gif](attachment:bruce.gif)
